# %% [markdown]
# ## Часть 1: Введение в Pandas
#
# Pandas - это библиотека Python для работы с данными. Она предоставляет мощные инструменты для анализа и манипуляции данными.
#
# ### Установка Pandas
#
# Для начала убедитесь, что у вас установлена библиотека Pandas. Если ее нет, установите ее с помощью команды:

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\manco\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.2.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manco\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manco\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\manco\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manco\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\manco\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: C:\Users\manco\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Импорт библиотеки
# Давайте начнем с импорта библиотеки Pandas:

# %%
# write your code here
import pandas as pd

# %% [markdown]
# ## Часть 2: Работа с данными
# ### Чтение данных
# Мы будем использовать датасет Titanic. Давайте прочитаем данные из CSV файла.

# %%
# Чтение данных из файла 'titanic.csv'
# Используйте метод pd.read_csv()
# write your code here
data = pd.read_csv("titanic.csv")

# %% [markdown]
# ### Предпросмотр данных
# Для первого ознакомления с данными давайте выведем первые несколько строк.

# %%
# Вывод первых 5 строк данных
# Используйте метод .head()
# write your code here
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Информация о данных
# Чтобы получить общую информацию о данных, воспользуйтесь методом .info().

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Работа с NaN
# Часто данные содержат пропущенные значения, которые представляются как NaN (Not a Number). Pandas предоставляет удобные методы для работы с ними.
#
# Проверка на наличие NaN. Методы fillna и dropna возвращают новые Dataframe, проверьте нет ли в них NaN

# %%
# Проверка на наличие NaN в DataFrame
# Используйте метод .isna()
# write your code here
print(data.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Заполнение NaN

# %%
# Заполнение NaN определенным значением (например, нулем)
# Используйте метод .fillna()
# write your code here
data.fillna(0, inplace=True)
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   0.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S
# 5      0            330877   8.4583     0        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750     0        S
# 8      2            347742  11.1333     0        S
# 9      0            237736  30.0708     0        C

# %% [markdown]
# Удаление строк с NaN

# %%
# Удаление строк, содержащих NaN
# Используйте метод .dropna()
# write your code here
data.dropna(inplace=True)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S

# %% [markdown]
# ## Часть 3: Обработка DataFrame
# ### Выбор данных
# Pandas позволяет выбирать данные по индексам, меткам столбцов и условиям.

# %%
# Выбор столбца по метке
# Используйте синтаксис DataFrame['название_столбца']
# write your code here
names = data["Name"]
print(names.head())

# Выбор нескольких столбцов
# Используйте синтаксис DataFrame[['столбец_1', 'столбец_2']]
# write your code here
names_ages = data[["Name", "Age"]]
print(names_ages.head())

# Выбор строк по индексу
# Используйте метод .loc[]
# write your code here
rowByThree = data.loc[3]
print(rowByThree.head())

# Выбор строк и столбцов по условию
# Используя логические операции, выберите мужчин старше 30
# write your code here
maleOver30 = data[(data['Sex']=="male") & (data['Age'] > 30)]
maleOver30.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Name: 3, dtype: object
#     PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 4             5         0       3     Allen, Mr. William Henry  male  35.0
# 6             7         0       1      McCarthy, Mr. Timothy J  male  54.0
# 13           14         0       3  Andersson, Mr. Anders Johan  male  39.0
# 20           21         0       2         Fynney, Mr. Joseph J  male  35.0
# 21           22         1       2        Beesley, Mr. Lawrence  male  34.0
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 4       0      0  373450   8.0500     0        S
# 6       0      0   17463  51.8625   E46        S
# 13      1      5  347082  31.2750     0        S
# 20      0      0  239865  26.0000     0        S
# 21      0      0  248698  13.0000   D56        S

# %% [markdown]
# ### Сортировка данных
# Сортировка данных по значениям столбцов.

# %%
# Сортировка данных по столбцу 'столбец_1' по возрастанию
# Используйте метод .sort_values()
# write your code here
sorted_data = data.sort_values(by='Age')
sorted_data.head()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 28            29         1       3      O'Dwyer, Miss. Ellen "Nellie"  female
# 593          594         0       3                 Bourke, Miss. Mary  female
# 457          458         1       1  Kenyon, Mrs. Frederick R (Marion)  female
# 454          455         0       3                Peduzzi, Mr. Joseph    male
# 451          452         0       3    Hagland, Mr. Ingvald Olai Olsen    male
#
#      Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 28   0.0      0      0    330959   7.8792     0        Q
# 593  0.0      0      2    364848   7.7500     0        Q
# 457  0.0      1      0     17464  51.8625   D21        S
# 454  0.0      0      0  A/5 2817   8.0500     0        S
# 451  0.0      1      0     65303  19.9667     0        S

# %% [markdown]
# ### Группировка данных
# Pandas также позволяет группировать данные и выполнять агрегирующие операции.

# %%
# Найдите долю выживших среди всех PClass
# Используйте метод .groupby()
# write your code here
meanSurv = data.groupby('Pclass')['Survived'].mean()
print(meanSurv)
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# ## Часть 4: Задания для практики
# Прочитайте данные из файла 'titanic.csv'.
# Проверьте, есть ли пропущенные значения в данных и заполните их нулями.
# Выведите первые 10 строк данных.
# Выберите только те строки, где значение в столбце 'Age' больше 30.
# Отсортируйте данные по столбцу 'Fare' в порядке убывания.
# Сгруппируйте данные по столбцу 'Pclass' и вычислите средний возраст ('Age') для каждого класса.

# %%
# Чтение данных из файла
titanic = pd.read_csv('titanic.csv')

# Проверка на наличие пустых значений
print(titanic.isna().sum())

# Заполнение всех пропущенных значений нулями
titanic.fillna(0, inplace=True)

# Вывод первых 10 строк данных
titanic.head(10)

# Age' > 30
age_above_30 = titanic[titanic['Age'] > 30]

# Сортировка данных по столбцу 'Fare'
sortedFare = age_above_30.sort_values(by='Fare', ascending=False)
print("Сортировка данных по столбцу 'Fare': ")
print(sortedFare)

# Группировка данных по столбцу 'Pclass' и средний возраст
avg_age = titanic.groupby('Pclass')['Age'].mean()
print("Группировка данных по столбцу 'Pclass' и средний возраст: ")
print(avg_age)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# Сортировка данных по столбцу 'Fare':
#      PassengerId  Survived  Pclass  \
# 679          680         1       1
# 737          738         1       1
# 258          259         1       1
# 438          439         0       1
# 299          300         1       1
# ..           ...       ...     ...
# 263          264         0       1
# 179          180         0       3
# 597          598         0       3
# 806          807         0       1
# 822          823         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 679               Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 737                           Lesurer, Mr. Gustave J    male  35.0      0
# 258                                 Ward, Miss. Anna  female  35.0      0
# 438                                Fortune, Mr. Mark    male  64.0      1
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# ..                                               ...     ...   ...    ...
# 263                            Harrison, Mr. William    male  40.0      0
# 179                              Leonard, Mr. Lionel    male  36.0      0
# 597                              Johnson, Mr. Alfred    male  49.0      0
# 806                           Andrews, Mr. Thomas Jr    male  39.0      0
# 822                  Reuchlin, Jonkheer. John George    male  38.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 679      1  PC 17755  512.3292  B51 B53 B55        C
# 737      0  PC 17755  512.3292         B101        C
# 258      0  PC 17755  512.3292            0        C
# 438      4     19950  263.0000  C23 C25 C27        S
# 299      1  PC 17558  247.5208      B58 B60        C
# ..     ...       ...       ...          ...      ...
# 263      0    112059    0.0000          B94        S
# 179      0      LINE    0.0000            0        S
# 597      0      LINE    0.0000            0        S
# 806      0    112050    0.0000          A36        S
# 822      0     19972    0.0000            0        S
#
# [305 rows x 12 columns]
# Группировка данных по столбцу 'Pclass' и средний возраст:
# Pclass
# 1    32.923241
# 2    28.091467
# 3    18.177026
# Name: Age, dtype: float64
